# %% [markdown]
# ### One of the biggest difference I noticed when I worked with "real" data in my NLP Engineer internship, was that I no longer had a neatly divided dataset ~ as a student I was most of the times blessed with having a divided dataset. Well, thats the real world where you need to deal with unstructured and messy data! <br> In my internship, I dealt with unstructured data from 2 different web scrapped sources and I had to build a NLP model to categorize products. While interacting with the dataset I realized that there were more than 50 categories and it the dataset was not distributed in a way where I could easily split the dataset as 70% training and 30% test/validate set. <br>This expereince taught me a lot and I wanted to look back at my university projects. <br> Thats why I am trying data analysis on this dataset as this AirBnB dataset has 1.4 (bad) usability index on Kaggle as it does not have any description available. As per my observation, no data is bad data thus what information I extract today may reveal new insights when I revisit it tomorrow. This is exactly why I wanted to explore this AirBnB data further and see what insights I can draw from it.
#
# ### Data Munging/Data Wrangling is defined as the process of transforming and mapping data from a raw data format to another format with the intent of making it more appropriate and valuable for a variety of downstream purposes such as analytics - *wikipedia
#
# ### Data Analysis is defined as a process of inspecting, cleansing, transforming, and modeling data with the goal of discovering useful information, informing conclusions, and supporting decision-making. - *wikipedia
#
# ### Dataset used:
# https://www.kaggle.com/gkdoad/airbnb

# %%
import pandas as pd

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df_main = pd.read_csv('./DataSets/listings.csv',index_col= 'id')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_main.head(2)
# Out:
#                           listing_url       scrape_id last_scraped  \
# id
# 109  https://www.airbnb.com/rooms/109  20190708161040   2019-07-09
# 344  https://www.airbnb.com/rooms/344  20190708161040   2019-07-09
#
#                                                   name  \
# id
# 109  Amazing bright elegant condo park front *UPGRA...
# 344                  Family perfect;Pool;Near Studios!
#
#                                                summary  \
# id
# 109  *** Unit upgraded with new bamboo flooring, br...
# 344  This home is perfect for families; aspiring ch...
#
#                                                  space  \
# id
# 109  *** Unit upgraded with new bamboo flooring, br...
# 344  Cheerful & comfortable; near studios, amusemen...
#
#                                            description experiences_offered  \
# id
# 109  *** Unit upgraded with new bamboo flooring, br...                none
# 344  This home is perfect for families; aspiring ch...                none
# ...

# %%
df_main.columns
# Out:
# Index(['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview', 'notes',
#        ...
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object', length=105)

# %%
df_main.describe()
# Out:
#           scrape_id  thumbnail_url  medium_url  xl_picture_url       host_id  \
# count  4.462000e+04            0.0         0.0             0.0  4.462000e+04
# mean   2.019071e+13            NaN         NaN             NaN  7.691035e+07
# std    1.343765e+01            NaN         NaN             NaN  7.805048e+07
# min    2.019071e+13            NaN         NaN             NaN  5.900000e+01
# 25%    2.019071e+13            NaN         NaN             NaN  1.203172e+07
# 50%    2.019071e+13            NaN         NaN             NaN  4.531206e+07
# 75%    2.019071e+13            NaN         NaN             NaN  1.297837e+08
# max    2.019071e+13            NaN         NaN             NaN  2.743889e+08
#
#        host_acceptance_rate  host_listings_count  host_total_listings_count  \
# count                   0.0         44606.000000               44606.000000
# mean                    NaN            15.982043                  15.982043
# ...

# %% [markdown]
# ## Drop the scrapping related columns

# %%
df_main[::1]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-2a36d1147950> in <module>
# ----> 1 df_main[::1]
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ...

# %%
df_main.drop(df_main[:])
